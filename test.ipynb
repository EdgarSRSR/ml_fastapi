# %%
import requests

url = "http://127.0.0.1:8000/predict"

payload = {"size_sqft": 1000, "bedrooms": 2}

# %%
response = requests.post(url, json=payload)

# %%
response.json()
# Out:
# {'predicted_price': 416.37769441280085}

# %%
url = "http://127.0.0.1:8000/predict_batch"

# %%
payload = {
    "houses" : [
        {"size_sqft" : 2000, "bedrooms": 3},
        {"size_sqft" : 1500, "bedrooms": 2},
        {"size_sqft" : 3200, "bedrooms": 5}
    ]
}

# %%
response = requests.post(url, json = payload)

# %%
response.json()
# Out:
# {'predicted_prices': [766.6823133993993,
#   566.0115359675078,
#   1227.8774048850646]}
